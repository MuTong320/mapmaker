# %%
from mapmaker import AltitudeMap, Map

# %%
p = AltitudeMap(
        name='s7777', seed=7777,
        land_level=0.5, sea_level=0.2, noise_level=0.5, 
        continent_number=4, slope=5, perlin_cells=(20,8), 
        longtitude_range=200, latitude_range=80, resolution=1
)
print(p)
p.plot('all')
# Out:
#         Random map s7777:
#             seed      : 7777,
#             continents: 4
#             size      : 200 x 80

# %%
m = Map(p, name='多块大陆', seed='2222')
m.polish(times=3)
print(m)
m.plot()
# Out:
# File 'data/多块大陆/city.txt' is empty.
# File 'data/多块大陆/river_name.txt' is empty.
#
#         Map 多块大陆:
#             random seed: 2222,
#             refine     : 5 cut times,
#             size       : 640 x 1600
#         Generate this map:
#             m = Map(name='多块大陆', seed='2222')
#             m.polish(5)
#         Read this map:
#             m = Map('data/多块大陆/map.txt', name='多块大陆', cut_time=5, seed='2222')

# %%
m.plot(which='陆地')

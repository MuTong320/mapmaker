# %%
from mapmaker import AltitudeMap, Map

# %%
p = AltitudeMap(
        name='s7777', seed=7777,
        land_level=0.5, sea_level=0.2, noise_level=0.5, 
        continent_number=3, slope=5, width_range=(0.25,0.75), height_range=(0.25,0.75),
        perlin_cells=(20,10), 
        longtitude_range=200, latitude_range=80, resolution=1
)
print(p)
p.plot('all')
# Out:
#         Random map s7777:
#             seed      : 7777,
#             continents: 3
#             size      : 200 x 80

# %%
m = Map(p, name='多块大陆', seed='2222')
m.polish(times=3)
print(m)
m.plot()
# Out:
# File 'data/多块大陆/city.txt' is empty.
# File 'data/多块大陆/river_name.txt' is empty.
#
#         Map 多块大陆:
#             random seed: 2222,
#             refine     : 3 cut times,
#             size       : 640 x 1600
#         Generate this map:
#             m = Map(name='多块大陆', seed='2222')
#             m.polish(3)
#         Read this map:
#             m = Map('data/多块大陆/map.txt', name='多块大陆', cut_time=3, seed='2222')

# %%
m.plot(which='陆地')

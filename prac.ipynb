# %%
import numpy as np
import numpy.random as random
import matplotlib.pyplot as plt
import pandas as pd
from mapmaker import *

# %%
m=Map(seed=7777)
m.plot()
# Out:
# File 'data/未命名地图/city.txt' is empty.
